# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhodip1/DataAnalysis_of_ICEcream/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3307d72b-e084-4f59-b816-b925440fa0f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3307d72b-e084-4f59-b816-b925440fa0f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
ice = pd.read_csv('IceCreamData.csv')
ice
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
ice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
sns.jointplot(x='Temperature',y='Revenue',data=ice,kind='reg')

# %%
y=ice['Revenue']
x=ice[['Temperature']]

# %%
x
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
ice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
y
# Out:
# 0      534.799028
# 1      625.190122
# 2      660.632289
# 3      487.706960
# 4      316.240194
#           ...
# 495    524.746364
# 496    755.818399
# 497    306.090719
# 498    566.217304
# 499    655.660388
# Name: Revenue, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
# We have 500 Rows and From that 500 Rows we have taken 30%
x_test
# Out:
#      Temperature
# 89     14.384083
# 217    22.653136
# 115    31.891468
# 85     16.364945
# 292    27.529232
# ..           ...
# 361    29.704183
# 282    26.078405
# 469    22.397977
# 101    32.004168
# 245    14.263541
#
# [150 rows x 1 columns]

# %%
x_train
# Out:
#      Temperature
# 284    22.146317
# 219    13.112452
# 464    17.455162
# 10     11.455253
# 28     19.024611
# ..           ...
# 489    26.964217
# 438    17.132795
# 55     27.312811
# 460    38.668202
# 163    27.931348
#
# [350 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression(fit_intercept=True)

# %%
x_test
# Out:
#      Temperature
# 89     14.384083
# 217    22.653136
# 115    31.891468
# 85     16.364945
# 292    27.529232
# ..           ...
# 361    29.704183
# 282    26.078405
# 469    22.397977
# 101    32.004168
# 245    14.263541
#
# [150 rows x 1 columns]

# %%
x_train
# Out:
#      Temperature
# 284    22.146317
# 219    13.112452
# 464    17.455162
# 10     11.455253
# 28     19.024611
# ..           ...
# 489    26.964217
# 438    17.132795
# 55     27.312811
# 460    38.668202
# 163    27.931348
#
# [350 rows x 1 columns]

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient(m):',linear.coef_)
print('Linear Model Coefficient(c):',linear.intercept_)
# Out:
# Linear Model Coefficient(m): [21.47251114]
# Linear Model Coefficient(c): 46.01763884145021

# %%
ice.iloc[150:199]
# Out:
#      Temperature     Revenue
# 150    24.548557  531.742485
# 151    12.209684  297.499120
# 152    12.265884  319.402903
# 153    19.754708  493.710333
# 154    23.349034  586.138767
# 155    21.144047  497.752318
# 156    18.880356  476.794525
# 157    28.271765  625.804642
# 158    16.406021  390.403349
# 159    28.993737  675.828916
# 160    10.245058  273.073342
# 161    11.077843  280.518467
# 162    25.499684  583.084449
# 163    27.931348  648.554644
# 164    28.459543  726.233771
# 165    13.301796  335.815687
# 166    25.995993  570.577875
# 167    32.805033  685.654655
# 168    32.716381  775.722858
# 169    32.107080  773.924755
# 170    24.778675  540.977511
# 171    15.029112  366.247714
# 172    23.424647  539.527740
# 173    35.217240  809.777726
# 174    16.379573  376.554472
# 175    20.556679  477.841719
# 176    21.322392  520.470310
# 177    26.943638  654.197406
# 178    22.634735  518.216105
# 179    33.250899  782.012550
# 180     8.991760  250.131728
# ...
